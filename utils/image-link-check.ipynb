# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/dc987/ydea/src/assets/csv/assets_final - Sheet2 (1).csv')

# %%
d = pd.read_csv('/Users/dc987/Desktop/images 2/clean.csv')

# %%
np.mean(df['link']==d['link'])
# Out:
# 1.0

# %%
np.mean(df['id']==d['id'])
# Out:
# 1.0

# %%
np.mean(df['img_link']==d['img_link'])
# Out:
# 1.0

# %%
len(df)
# Out:
# 15030

# %%
len(df['id'].unique())
# Out:
# 15030

# %%
len(df['link'].unique())
# Out:
# 15030

# %%
len(df['img_link'].unique())
# Out:
# 14058

# %%
l = df.img_link.value_counts().index[6]

# %%
l
# Out:
# 'https://stor.artstor.org/iiif/fpx/sslps/c7730479/3929232.fpx/full/,1024/0/default.jpg'

# %%
df.link[df.img_link==l].iloc[0]
# Out:
# 'https://library.artstor.org/#/asset/SS7730479_7730479_10857965'

# %%
df.link[df.img_link==l].iloc[1]
# Out:
# 'https://library.artstor.org/#/asset/SS7730479_7730479_10854973'

# %%
df.link[df.img_link==l].iloc[2]
# Out:
# 'https://library.artstor.org/#/asset/SS7730479_7730479_10859996'

# %%
df.link[df.img_link==l].iloc[3]
# Out:
# 'https://library.artstor.org/#/asset/SS7730479_7730479_10855031'

# %%
df.link[df.img_link==l].iloc[4]
# Out:
# 'https://library.artstor.org/#/asset/SS7730479_7730479_10855053'

# %%
df.link[df.img_link==l].iloc[5]
# Out:
# 'https://library.artstor.org/#/asset/SS7730479_7730479_10854899'

# %%
df['id'][df.img_link==l].iloc[0]
# Out:
# 663

# %%
df['id'][df.img_link==l].iloc[1]
# Out:
# 664

# %%
df['id'][df.img_link==l].iloc[2]
# Out:
# 665

# %%
from PIL import Image

# %%
DIR = '/Users/dc987/Desktop/images/'

# %%
Image.open(DIR+'669.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=981x1024 at 0x7FF2187438D0>

# %%
df['localpath'] = [DIR + str(item) + '.jpg' for item in df['id']]

# %%
tmp = df.img_link.value_counts()

# %%
tmp = tmp[tmp>3]

# %%
import sys
sys.path.append('/Users/dc987/ivpy/src/')
from ivpy import *

# %%
counter = -1
for idx in tmp.index:
    counter+=1
    impaths = df.localpath[df.img_link==idx]
    show(pd.Series(impaths)).save('/Users/dc987/Desktop/linktest/'+str(counter)+'.jpg')

# %%
df[['id','name','accession','negative_number']][df.img_link==l]
# Out:
#       id                      name   accession negative_number
# 662  663  Bronze Scales (7 scales)  1938.3668g   1938'3668g~01
# 663  664  Bronze Scales (3 scales)  1938.3668g   1938'3668g~01
# 664  665    Bronze Pendant or Hook  1938.3668g   1938'3668g~01
# 665  666  Bronze Scales (6 scales)  1938.3668g   1938'3668g~01
# 666  667  Bronze Scales (9 scales)  1938.3668g   1938'3668g~01
# 667  668  Bronze Scales (3 scales)  1938.3668g   1938'3668g~01

# %%
for link in df.link[df.img_link==l]:
    print(link)
# Out:
# https://library.artstor.org/#/asset/SS7730479_7730479_10857965
# https://library.artstor.org/#/asset/SS7730479_7730479_10854973
# https://library.artstor.org/#/asset/SS7730479_7730479_10859996
# https://library.artstor.org/#/asset/SS7730479_7730479_10855031
# https://library.artstor.org/#/asset/SS7730479_7730479_10855053
# https://library.artstor.org/#/asset/SS7730479_7730479_10854899
