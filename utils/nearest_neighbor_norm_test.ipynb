# %%
import pandas as pd
import sys
sys.path.append('/Users/dc987/ivpy/src')
from ivpy.analysis import nearest
from ivpy import *

# %%
X = pd.read_csv('/Users/dc987/ydea/src/assets/csv/XduraEuropos.csv')

# %%
df = pd.read_csv('/Users/dc987/ydea/src/assets/csv/master.csv')

# %%
attach(df,'localpath')

# %%
from ivpy.extract import norm
# Out:
# Using TensorFlow backend.

# %%
Xn = norm(X)

# %%
nn = nearest(X,i=500,k=100)
nnn = nearest(Xn,i=500,k=100)

# %%
show(df.localpath.loc[nn])
# Out:
# <PIL.Image.Image image mode=RGB size=900x1200 at 0x7FFD62975588>

# %%
show(df.localpath.loc[nnn])
# Out:
# <PIL.Image.Image image mode=RGB size=900x1200 at 0x7FFD51CDA0F0>

# %%
len(set(nn).intersection(set(nnn))) / len(set(nn).union(set(nnn)))
# Out:
# 0.941747572815534
